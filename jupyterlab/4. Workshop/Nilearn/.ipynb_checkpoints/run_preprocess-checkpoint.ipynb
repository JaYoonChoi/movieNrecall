# %% [markdown]
# # Reference
# - dcm2nifti & change file name : Thanks to 강민석 교수님..
# - Denoising process: https://github.com/cosanlab/vmPFC_dynamics/blob/master/Notebooks/1_VMPFC_Denoise.ipynb

# %% [markdown]
# # 0. Make a BIDS format

# %%
# Change fieldmap name with shell script !                 
path = '/mnt/c/Users/since/Desktop/Kdrama_prac/bash_create_folders_in_nifti.sh' #파일이 존재하는 로컬 경로 설정. 스크립트 들어가서 먼저 변수 설정 바꿔주기.. 
sp.call(path, shell=True)

# %% [markdown]
# # 1. dcm2nifti : Conver dcm data to nifti

# %% [raw]
# - 설치 리스트
# conda install -c conda-forge dcm2niix

# %%
from nipype.interfaces.dcm2nii import Dcm2niix
import nipype.interfaces.io as nio
import warnings
import subprocess as sp

warnings.filterwarnings(action='ignore')

# %%
subjsource = nio.DataGrabber()

# %%
subjsource.inputs.base_directory = '/mnt/c/Users/since/Desktop/Kdrama_prac/dicom' # make sure to change output directory below
#subjsource.inputs.template = 'S1[0-5]'
subjsource.inputs.template = 'S1[1,5]'
subjsource.inputs.sort_filelist = True
subjresults = subjsource.run()

converter = Dcm2niix()

if isinstance(subjresults.outputs.outfiles,str):
    subjresults.outputs.outfiles = [subjresults.outputs.outfiles]
    
print(subjresults.outputs.outfiles)
# Out:
# ['/mnt/c/Users/since/Desktop/Kdrama_prac/dicom/S11', '/mnt/c/Users/since/Desktop/Kdrama_prac/dicom/S15']

# %%
# Convert Dicom to nifti : sub- 11 & 15 
for cur_subj in subjresults.outputs.outfiles:
    cur_len = len(cur_subj)
    cur_sid = 'sub-' + cur_subj[cur_len-2:cur_len]
    res_dir = cur_subj[0:cur_len-9]+'data/'
    print(res_dir)
    print('%s' %cur_sid)
    
    #for cur_type in ['*ENCODING*','*RECALL*','T2*','T1*','GRE*','PA*']:
    for cur_type in ['ENCODING*', 'RECALL*', 'T1*', 'GRE*', 'PA*']:       
        if cur_type == 'T1*' or cur_type == 'T2*':
            cur_subdir = '/anat'
        elif cur_type == 'GRE*' or cur_type == 'PA*':
            cur_subdir = '/fmap'
        else: 
            cur_subdir = '/func'
            
        #Grab Relevant Data
        datasource = nio.DataGrabber()
        datasource.inputs.base_directory = cur_subj
        datasource.inputs.template = cur_type
        datasource.inputs.sort_filelist = True
        datasource.inputs.raise_on_empty = False
        results = datasource.run()
        
        idx = 1
        if results.outputs.outfiles is not None:
            if isinstance(results.outputs.outfiles,str):
                results.outputs.outfiles = [results.outputs.outfiles]

        for cur_file in results.outputs.outfiles:
                print('cur_file is', cur_file)
                
                # set output file name
                if cur_type == 'T1*':
                    cur_output_filename = cur_sid + '_T1w'
                #elif cur_type == 'T2*':
                #    cur_output_filename = cur_sid + '_T2w'
                elif cur_type == 'GRE*':
                    cur_output_filename = cur_sid + '_fmap'
                elif cur_type == 'ENCODING*':
                    cur_output_filename = cur_sid + '_task-encoding_run-' + str(idx) + '_bold'
                elif cur_type == 'RECALL*':
                    cur_output_filename = cur_sid + '_task-recall_run-' + str(idx) + '_bold'
                elif cur_type == 'PA*':
                    cur_output_filename = cur_sid + '_dir-pa' + '_epi'
                              
                converter.inputs.source_dir = cur_file
                converter.inputs.compression = 5
                converter.inputs.bids_format = True
                converter.inputs.output_dir = res_dir + cur_sid + cur_subdir 
                converter.inputs.out_filename = cur_output_filename
                converter.run()
                idx = idx + 1

                print(converter.inputs.output_dir + '/' + converter.inputs.out_filename)
                
# Change fieldmap name with shell script !                 
path = '/mnt/c/Users/since/Desktop/Kdrama_prac/bash_change_fieldmap_name_May.sh' #파일이 존재하는 로컬 경로 설정 
sp.call(path, shell=True)
# Out:
# /mnt/c/Users/since/Desktop/Kdrama_prac/data/
# sub-11
# cur_file is /mnt/c/Users/since/Desktop/Kdrama_prac/dicom/S11/ENCODING-1_0008
# 230711-14:05:56,736 nipype.interface INFO:
# 	 stdout 2023-07-11T14:05:56.736763:Chris Rorden's dcm2niiX version v1.0.20220720  GCC10.4.0 x86-64 (64-bit Linux)
# 230711-14:05:56,737 nipype.interface INFO:
# 	 stdout 2023-07-11T14:05:56.736763:Found 477 DICOM file(s)
# 230711-14:05:56,738 nipype.interface INFO:
# 	 stdout 2023-07-11T14:05:56.736763:Convert 477 DICOM as /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/func/sub-11_task-encoding_run-1_bold (80x80x48x477)
# 230711-14:05:57,557 nipype.interface INFO:
# 	 stdout 2023-07-11T14:05:57.557947:Compress: "/usr/bin/pigz" -b 960 -n -f -5 "/mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/func/sub-11_task-encoding_run-1_bold.nii"
# 230711-14:05:57,558 nipype.interface INFO:
# 	 stdout 2023-07-11T14:05:57.557947:Conversion required 14.018442 seconds (1.963837 for core code).
# /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/func/sub-11_task-encoding_run-1_bold
# cur_file is /mnt/c/Users/since/Desktop/Kdrama_prac/dicom/S11/ENCODING-3_0010
# 230711-14:06:10,986 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:10.986357:Chris Rorden's dcm2niiX version v1.0.20220720  GCC10.4.0 x86-64 (64-bit Linux)
# 230711-14:06:10,987 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:10.986357:Found 477 DICOM file(s)
# 230711-14:06:10,987 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:10.986357:Convert 477 DICOM as /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/func/sub-11_task-encoding_run-2_bold (80x80x48x477)
# 230711-14:06:11,866 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:11.866310:Compress: "/usr/bin/pigz" -b 960 -n -f -5 "/mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/func/sub-11_task-encoding_run-2_bold.nii"
# 230711-14:06:11,867 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:11.866310:Conversion required 14.187997 seconds (1.966965 for core code).
# /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/func/sub-11_task-encoding_run-2_bold
# cur_file is /mnt/c/Users/since/Desktop/Kdrama_prac/dicom/S11/RECALL-1_0009
# 230711-14:06:24,970 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:24.970001:Chris Rorden's dcm2niiX version v1.0.20220720  GCC10.4.0 x86-64 (64-bit Linux)
# 230711-14:06:24,970 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:24.970001:Found 471 DICOM file(s)
# 230711-14:06:24,971 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:24.970001:Convert 471 DICOM as /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/func/sub-11_task-recall_run-1_bold (80x80x48x471)
# 230711-14:06:25,820 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:25.820171:Compress: "/usr/bin/pigz" -b 960 -n -f -5 "/mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/func/sub-11_task-recall_run-1_bold.nii"
# 230711-14:06:25,820 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:25.820171:Conversion required 13.837510 seconds (1.936159 for core code).
# /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/func/sub-11_task-recall_run-1_bold
# cur_file is /mnt/c/Users/since/Desktop/Kdrama_prac/dicom/S11/RECALL-2_0011
# 230711-14:06:45,620 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:45.619954:Chris Rorden's dcm2niiX version v1.0.20220720  GCC10.4.0 x86-64 (64-bit Linux)
# 230711-14:06:45,620 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:45.619954:Found 732 DICOM file(s)
# 230711-14:06:45,621 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:45.619954:Convert 732 DICOM as /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/func/sub-11_task-recall_run-2_bold (80x80x48x732)
# 230711-14:06:46,892 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:46.892406:Compress: "/usr/bin/pigz" -b 960 -n -f -5 "/mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/func/sub-11_task-recall_run-2_bold.nii"
# 230711-14:06:46,893 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:46.892406:Conversion required 20.948799 seconds (2.965196 for core code).
# /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/func/sub-11_task-recall_run-2_bold
# cur_file is /mnt/c/Users/since/Desktop/Kdrama_prac/dicom/S11/T1_MPRAGE_SAG_1_0ISO_0005
# 230711-14:06:52,308 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:52.308670:Chris Rorden's dcm2niiX version v1.0.20220720  GCC10.4.0 x86-64 (64-bit Linux)
# 230711-14:06:52,309 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:52.308670:Found 192 DICOM file(s)
# 230711-14:06:52,309 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:52.308670:Convert 192 DICOM as /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/anat/sub-11_T1w (256x256x192x1)
# 230711-14:06:52,554 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:52.554583:Compress: "/usr/bin/pigz" -b 960 -n -f -5 "/mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/anat/sub-11_T1w.nii"
# 230711-14:06:52,555 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:52.554583:Conversion required 5.538273 seconds (0.817207 for core code).
# /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/anat/sub-11_T1w
# cur_file is /mnt/c/Users/since/Desktop/Kdrama_prac/dicom/S11/GRE_FIELD_MAPPING_3MM_0013
# 230711-14:06:56,259 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:56.259000:Chris Rorden's dcm2niiX version v1.0.20220720  GCC10.4.0 x86-64 (64-bit Linux)
# 230711-14:06:56,259 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:56.259000:Found 144 DICOM file(s)
# 230711-14:06:56,260 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:56.259000:Slices not stacked: echo varies (TE 4.92, 7.38; echo 1, 2). Use 'merge 2D slices' option to force stacking
# 230711-14:06:56,260 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:56.259000:Convert 72 DICOM as /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/fmap/sub-11_fmap_e1 (110x110x72x1)
# 230711-14:06:56,779 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:56.779346:Compress: "/usr/bin/pigz" -b 960 -n -f -5 "/mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/fmap/sub-11_fmap_e1.nii"
# 230711-14:06:56,779 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:56.779346:Convert 72 DICOM as /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/fmap/sub-11_fmap_e2 (110x110x72x1)
# 230711-14:06:56,859 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:56.859573:Compress: "/usr/bin/pigz" -b 960 -n -f -5 "/mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/fmap/sub-11_fmap_e2.nii"
# 230711-14:06:56,860 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:56.859573:Conversion required 4.179852 seconds (0.567786 for core code).
# /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/fmap/sub-11_fmap
# cur_file is /mnt/c/Users/since/Desktop/Kdrama_prac/dicom/S11/GRE_FIELD_MAPPING_3MM_0014
# 230711-14:06:59,47 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:59.047390:Chris Rorden's dcm2niiX version v1.0.20220720  GCC10.4.0 x86-64 (64-bit Linux)
# 230711-14:06:59,48 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:59.047390:Found 72 DICOM file(s)
# 230711-14:06:59,48 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:59.047390:Convert 72 DICOM as /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/fmap/sub-11_fmap_e2_ph (110x110x72x1)
# 230711-14:06:59,134 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:59.134163:Compress: "/usr/bin/pigz" -b 960 -n -f -5 "/mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/fmap/sub-11_fmap_e2_ph.nii"
# 230711-14:06:59,134 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:59.134163:Conversion required 2.120787 seconds (0.285993 for core code).
# /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/fmap/sub-11_fmap
# cur_file is /mnt/c/Users/since/Desktop/Kdrama_prac/dicom/S11/PA_MOVIE_0012
# 230711-14:06:59,945 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:59.945286:Chris Rorden's dcm2niiX version v1.0.20220720  GCC10.4.0 x86-64 (64-bit Linux)
# 230711-14:06:59,946 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:59.945286:Found 20 DICOM file(s)
# 230711-14:06:59,946 nipype.interface INFO:
# 	 stdout 2023-07-11T14:06:59.945286:Convert 20 DICOM as /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/fmap/sub-11_dir-pa_epi (80x80x48x20)
# 230711-14:07:00,64 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:00.064372:Compress: "/usr/bin/pigz" -b 960 -n -f -5 "/mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/fmap/sub-11_dir-pa_epi.nii"
# 230711-14:07:00,65 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:00.064372:Conversion required 0.786216 seconds (0.101992 for core code).
# /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-11/fmap/sub-11_dir-pa_epi
# /mnt/c/Users/since/Desktop/Kdrama_prac/data/
# sub-15
# cur_file is /mnt/c/Users/since/Desktop/Kdrama_prac/dicom/S15/ENCODING-1_0007
# 230711-14:07:11,705 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:11.705536:Chris Rorden's dcm2niiX version v1.0.20220720  GCC10.4.0 x86-64 (64-bit Linux)
# 230711-14:07:11,706 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:11.705536:Found 477 DICOM file(s)
# 230711-14:07:11,706 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:11.705536:Convert 477 DICOM as /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/func/sub-15_task-encoding_run-1_bolda (80x80x48x477)
# 230711-14:07:12,553 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:12.553379:Compress: "/usr/bin/pigz" -b 960 -n -f -5 "/mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/func/sub-15_task-encoding_run-1_bolda.nii"
# 230711-14:07:12,553 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:12.553379:Conversion required 12.353541 seconds (1.948143 for core code).
# /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/func/sub-15_task-encoding_run-1_bold
# cur_file is /mnt/c/Users/since/Desktop/Kdrama_prac/dicom/S15/ENCODING-3_0009
# 230711-14:07:24,329 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:24.329058:Chris Rorden's dcm2niiX version v1.0.20220720  GCC10.4.0 x86-64 (64-bit Linux)
# 230711-14:07:24,329 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:24.329058:Found 477 DICOM file(s)
# 230711-14:07:24,330 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:24.329058:Convert 477 DICOM as /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/func/sub-15_task-encoding_run-2_bolda (80x80x48x477)
# 230711-14:07:25,184 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:25.184669:Compress: "/usr/bin/pigz" -b 960 -n -f -5 "/mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/func/sub-15_task-encoding_run-2_bolda.nii"
# 230711-14:07:25,185 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:25.184669:Conversion required 12.520098 seconds (1.971668 for core code).
# /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/func/sub-15_task-encoding_run-2_bold
# cur_file is /mnt/c/Users/since/Desktop/Kdrama_prac/dicom/S15/RECALL-1_0008
# 230711-14:07:31,116 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:31.116709:Chris Rorden's dcm2niiX version v1.0.20220720  GCC10.4.0 x86-64 (64-bit Linux)
# 230711-14:07:31,117 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:31.116709:Found 247 DICOM file(s)
# 230711-14:07:31,117 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:31.116709:Convert 247 DICOM as /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/func/sub-15_task-recall_run-1_bolda (80x80x48x247)
# 230711-14:07:31,616 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:31.616154:Compress: "/usr/bin/pigz" -b 960 -n -f -5 "/mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/func/sub-15_task-recall_run-1_bolda.nii"
# 230711-14:07:31,616 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:31.616154:Conversion required 6.308863 seconds (1.012364 for core code).
# /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/func/sub-15_task-recall_run-1_bold
# cur_file is /mnt/c/Users/since/Desktop/Kdrama_prac/dicom/S15/RECALL-2_0010
# 230711-14:07:40,283 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:40.283791:Chris Rorden's dcm2niiX version v1.0.20220720  GCC10.4.0 x86-64 (64-bit Linux)
# 230711-14:07:40,284 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:40.283791:Found 356 DICOM file(s)
# 230711-14:07:40,285 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:40.283791:Convert 356 DICOM as /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/func/sub-15_task-recall_run-2_bolda (80x80x48x356)
# 230711-14:07:40,957 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:40.957149:Compress: "/usr/bin/pigz" -b 960 -n -f -5 "/mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/func/sub-15_task-recall_run-2_bolda.nii"
# 230711-14:07:40,957 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:40.957149:Conversion required 9.224709 seconds (1.464088 for core code).
# /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/func/sub-15_task-recall_run-2_bold
# cur_file is /mnt/c/Users/since/Desktop/Kdrama_prac/dicom/S15/T1_MPRAGE_SAG_1_0ISO_0005
# 230711-14:07:45,805 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:45.804959:Chris Rorden's dcm2niiX version v1.0.20220720  GCC10.4.0 x86-64 (64-bit Linux)
# 230711-14:07:45,805 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:45.804959:Found 192 DICOM file(s)
# 230711-14:07:45,806 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:45.804959:Convert 192 DICOM as /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/anat/sub-15_T1wa (256x256x192x1)
# 230711-14:07:46,42 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:46.042212:Compress: "/usr/bin/pigz" -b 960 -n -f -5 "/mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/anat/sub-15_T1wa.nii"
# 230711-14:07:46,42 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:46.042212:Conversion required 4.962416 seconds (0.808478 for core code).
# /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/anat/sub-15_T1w
# cur_file is /mnt/c/Users/since/Desktop/Kdrama_prac/dicom/S15/GRE_FIELD_MAPPING_3MM_0012
# 230711-14:07:49,162 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:49.162004:Chris Rorden's dcm2niiX version v1.0.20220720  GCC10.4.0 x86-64 (64-bit Linux)
# 230711-14:07:49,162 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:49.162004:Found 144 DICOM file(s)
# 230711-14:07:49,163 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:49.162004:Slices not stacked: echo varies (TE 4.92, 7.38; echo 1, 2). Use 'merge 2D slices' option to force stacking
# 230711-14:07:49,163 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:49.162004:Convert 72 DICOM as /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/fmap/sub-15_fmap_e1 (110x110x72x1)
# 230711-14:07:49,696 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:49.696361:Compress: "/usr/bin/pigz" -b 960 -n -f -5 "/mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/fmap/sub-15_fmap_e1.nii"
# 230711-14:07:49,697 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:49.696361:Convert 72 DICOM as /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/fmap/sub-15_fmap_e2 (110x110x72x1)
# 230711-14:07:49,779 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:49.779273:Compress: "/usr/bin/pigz" -b 960 -n -f -5 "/mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/fmap/sub-15_fmap_e2.nii"
# 230711-14:07:49,779 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:49.779273:Conversion required 3.613115 seconds (0.561785 for core code).
# /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/fmap/sub-15_fmap
# cur_file is /mnt/c/Users/since/Desktop/Kdrama_prac/dicom/S15/GRE_FIELD_MAPPING_3MM_0013
# 230711-14:07:51,662 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:51.662227:Chris Rorden's dcm2niiX version v1.0.20220720  GCC10.4.0 x86-64 (64-bit Linux)
# 230711-14:07:51,663 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:51.662227:Found 72 DICOM file(s)
# 230711-14:07:51,663 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:51.662227:Convert 72 DICOM as /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/fmap/sub-15_fmap_e2_ph (110x110x72x1)
# 230711-14:07:51,748 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:51.748815:Compress: "/usr/bin/pigz" -b 960 -n -f -5 "/mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/fmap/sub-15_fmap_e2_ph.nii"
# 230711-14:07:51,749 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:51.748815:Conversion required 1.813269 seconds (0.282640 for core code).
# /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/fmap/sub-15_fmap
# cur_file is /mnt/c/Users/since/Desktop/Kdrama_prac/dicom/S15/PA_MOVIE_0011
# 230711-14:07:52,447 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:52.447652:Chris Rorden's dcm2niiX version v1.0.20220720  GCC10.4.0 x86-64 (64-bit Linux)
# 230711-14:07:52,448 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:52.447652:Found 20 DICOM file(s)
# 230711-14:07:52,449 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:52.447652:Convert 20 DICOM as /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/fmap/sub-15_dir-pa_epia (80x80x48x20)
# 230711-14:07:52,575 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:52.575370:Compress: "/usr/bin/pigz" -b 960 -n -f -5 "/mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/fmap/sub-15_dir-pa_epia.nii"
# 230711-14:07:52,576 nipype.interface INFO:
# 	 stdout 2023-07-11T14:07:52.575370:Conversion required 0.692125 seconds (0.098256 for core code).
# /mnt/c/Users/since/Desktop/Kdrama_prac/data/sub-15/fmap/sub-15_dir-pa_epi

# %% [markdown]
# # 2. Run fMRIprep

# %% [raw]
# # Run fMRIPrep
# 1. 여기 부분은 우분투에서 직접 도커를 실행
# 2. fMRIPrep 스크립트를 진행
#
# prerequest
# 1. Licence for freesufer @ license file
# 2. dataset_description.jason @ DATA file
# 3. Docker and fMRIPrep

# %% [markdown]
# # 3. (Optional but necessary..) Denoising

# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from nltools.stats import regress, zscore
from nltools.data import Brain_Data, Design_Matrix
from nltools.stats import find_spikes 
from nltools.mask import expand_mask

base_dir = '/mnt/c/Users/since/Desktop/Kdrama_prac/'
data_dir = os.path.join(base_dir, 'data2', 'derivatives')
denoised_dir = os.path.join(base_dir, 'analysis', 'denoised')
# Out:
# /home/sincerely/.conda/envs/fmri01/lib/python3.7/site-packages/nilearn/__init__.py:69: FutureWarning: Python 3.7 support is deprecated and will be removed in release 0.12 of Nilearn. Consider switching to Python 3.9 or 3.10.
#   _python_deprecation_warnings()

# %%
subjects = ['14','15', '16'] 
fwhm = 6
tr = 1.5
outlier_cutoff = 3

# %%
for s in subjects:
    print(s)
    file_list = glob.glob(os.path.join(data_dir, f'sub-{s}', 'func', '*preproc*.nii.gz'))
    print(len(file_list))
    for f in file_list:
        sub = os.path.basename(f).split('_')[0]
        task = os.path.basename(f).split('_')[1]
        run = os.path.basename(f).split('_')[2]
           
        # if not os.path.exists(result_dir):
        #     os.makedirs(result_dir)
        csf = Brain_Data(glob.glob(os.path.join(data_dir, f'{sub}', 'anat', '*CSF*.nii.gz'))[1])
        data = Brain_Data(f) #denoise 
        smoothed = data.smooth(fwhm=fwhm)   # Spatial smoothing 
        
        spikes = smoothed.find_spikes(global_spike_cutoff=outlier_cutoff, diff_spike_cutoff=outlier_cutoff) #FD가 2std 초과하는 것들만 Outlier로 만들었다. 
        covariates = pd.read_csv(glob.glob(os.path.join(data_dir, sub, 'func', f'{sub}_{task}_{run}_desc-confounds_timeseries.tsv'))[0], sep='\t') #Motion params !! 
        
        mc = covariates[['trans_x','trans_y','trans_z','rot_x', 'rot_y', 'rot_z']]
        mc_cov = make_motion_covariates(mc, tr)
        motionOutliers = covariates.filter(regex='motion_outlier')
        
        csf = zscore(pd.Series(smoothed.extract_roi(csf.threshold(upper=0.85, binarize=True)))) # Use CSF from fmriprep output
        
        dm = Design_Matrix(pd.concat([csf, mc_cov, motionOutliers, spikes.drop(labels='TR', axis=1)], axis=1), sampling_freq=1/tr)
        dm = dm.add_poly(order=2, include_lower=True) # Add Intercept, Linear and Quadratic Trends

        smoothed.X = dm 
        stats = smoothed.regress()
        stats['residual'].data = np.float32(stats['residual'].data) # cast as float32 to reduce storage space
        stats['residual'].write(os.path.join(denoised_dir, f'{sub}_denoise_{task}_{run}_space-MNI152NLin6Asym_desc-preproc_bold.nii.gz'))
        print( f'finisih_{sub}_{task}_{run}_data')
# Out:
# 14
# 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1078/2977358251.py in <module>
#      11         #     os.makedirs(result_dir)
#      12         csf = Brain_Data(glob.glob(os.path.join(data_dir, f'{sub}', 'anat', '*CSF*.nii.gz'))[1])
# ---> 13         data = Brain_Data(f) #denoise
#      14         smoothed = data.smooth(fwhm=fwhm)   # Spatial smoothing
#      15
#
# ~/.conda/envs/fmri01/lib/python3.7/site-packages/nltools/data/brain_data.py in __init__(self, data, Y, X, mask, **kwargs)
#     177                 else:
#     178                     data = nib.load(data)
# --> 179                 self.data = self.nifti_masker.fit_transform(data)
#     180             elif isinstance(data, list):
#     181                 if isinstance(data[0], Brain_Data):
#
# ~/.conda/envs/fmri01/lib/python3.7/site-packages/nilearn/maskers/base_masker.py in fit_transform(self, X, y, confounds, sample_mask, **fit_params)
#     289                 return self.fit(**fit_params).transform(X,
#     290                                                         confounds=confounds,
# --> 291                                                         sample_mask=sample_mask
#     292                                                         )
#     293         else:
#
# ~/.conda/envs/fmri01/lib/python3.7/site-packages/nilearn/maskers/base_masker.py in transform(self, imgs, confounds, sample_mask)
#     233             return self.transform_single_imgs(imgs,
#     234                                               confounds=confounds,
# --> 235                                               sample_mask=sample_mask)
#     236
#     237         # Compute high variance confounds if requested
#
# ~/.conda/envs/fmri01/lib/python3.7/site-packages/nilearn/maskers/nifti_masker.py in transform_single_imgs(self, imgs, confounds, sample_mask, copy)
#     587             sample_mask=sample_mask,
#     588             copy=copy,
# --> 589             dtype=self.dtype,
#     590         )
#     591
#
# ~/.conda/envs/fmri01/lib/python3.7/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     347
#     348     def __call__(self, *args, **kwargs):
# --> 349         return self.func(*args, **kwargs)
#     350
#     351     def call_and_shelve(self, *args, **kwargs):
#
# ~/.conda/envs/fmri01/lib/python3.7/site-packages/nilearn/maskers/nifti_masker.py in _filter_and_mask(imgs, mask_img_, parameters, memory_level, memory, verbose, confounds, sample_mask, copy, dtype)
#     116         sample_mask=sample_mask,
#     117         copy=copy,
# --> 118         dtype=dtype
#     119     )
#     120     # For _later_: missing value removal or imputing of missing data
#
# ~/.conda/envs/fmri01/lib/python3.7/site-packages/nilearn/maskers/base_masker.py in _filter_and_extract(imgs, extraction_function, parameters, memory_level, memory, verbose, confounds, sample_mask, copy, dtype)
#      97                 target_shape=target_shape,
#      98                 target_affine=target_affine,
# ---> 99                 copy=copy)
#     100
#     101     smoothing_fwhm = parameters.get('smoothing_fwhm')
#
# ~/.conda/envs/fmri01/lib/python3.7/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     347
#     348     def __call__(self, *args, **kwargs):
# --> 349         return self.func(*args, **kwargs)
#     350
#     351     def call_and_shelve(self, *args, **kwargs):
#
# ~/.conda/envs/fmri01/lib/python3.7/site-packages/nilearn/image/resampling.py in resample_img(img, target_affine, target_shape, interpolation, copy, order, clip, fill_value, force_resample)
#     614                               out=resampled_data[all_img + ind],
#     615                               copy=not input_img_is_string,
# --> 616                               fill_value=fill_value)
#     617
#     618     if clip:
#
# ~/.conda/envs/fmri01/lib/python3.7/site-packages/nilearn/image/resampling.py in _resample_one_img(data, A, b, target_shape, interpolation_order, out, copy, fill_value)
#     288             output=out,
#     289             cval=fill_value,
# --> 290             order=interpolation_order,
#     291         )
#     292
#
# ~/.conda/envs/fmri01/lib/python3.7/site-packages/scipy/ndimage/interpolation.py in affine_transform(input, matrix, offset, output_shape, output, order, mode, cval, prefilter)
#     607         )
#     608         _nd_image.zoom_shift(filtered, matrix, offset/matrix, output, order,
# --> 609                              mode, cval, npad, False)
#     610     else:
#     611         _nd_image.geometric_transform(filtered, None, None, matrix, offset,
#
# KeyboardInterrupt:

# %%
# Make hdf5 for efficient calculation 
file_list = glob.glob(os.path.join(denoised_dir, '*.nii.gz'))
#print(file_list)
for f in file_list:
    data = Brain_Data(f)
    data.write(f"{f.split('.nii.gz')[0]}.hdf5")
    print('finish'+f"{f.split('.nii.gz')[0]}.hdf5")

# %%
# Average for each ROI 
mask = Brain_Data('http://neurovault.org/media/images/2099/Neurosynth%20Parcellation_0.nii.gz') #3iso 짜리, Dartbrain에서 사용한 ROI인데 cortex 쪽에만 존재한다. 
#mask = Brain_Data(mask_path)
mask_x = expand_mask(mask)

file_list = glob.glob(os.path.join(denoised_dir, f'*.hdf5'))
for f in file_list:
    sub = os.path.basename(f).split('_')[0]
    task = os.path.basename(f).split('_')[2]
    run = os.path.basename(f).split('_')[3]    
    data = Brain_Data(f)
    # for i,m in enumerate(mask_x):  #for masking each ROI
    #     roi = data.apply_mask(m)
    #     pd.DataFrame(roi.data).to_csv(os.path.join(denoised_dir, 'ROIs', f'{sub}_{task}_{run}_denoised_roi{i}.csv' ), index=False)
    avg_roi = data.extract_roi(mask)
    pd.DataFrame(avg_roi.T).to_csv(os.path.join(denoised_dir, 'Averaged_ROI', f'{sub}_{task}_{run}_Average_ROI_n50.csv'), index=False)
    print(f'finish_{sub}_{task}_{run}')
